# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
N_SAMPLES = 100
N_FEATS = 1

# %%
### Using sklearn to generate simulated data 

# params
noise = 10

#Generate
X, y = make_regression(N_SAMPLES, N_FEATS, noise=noise)


#plot
fig, ax = plt.subplots()
ax.scatter(X,y)
plt.show()

# %%
### Using a ramdom points sampled uniformly from a line and adding gaussian noise to generate simulated data


X = np.random.rand(N_SAMPLES)*100 -50


#params of line
m = 3
b = 1


y = X*m + b


#params of gaussian noise
center = 0
std = 10

noise = np.random.normal(center,std,N_SAMPLES)

#mix line and noise
y = y + noise


#plot
fig2, ax2 = plt.subplots()
ax2.scatter(X,y)
plt.show()

# %%
### using two gaussians, one bigg in front of the other
#params of gaussian sampling
center1 = 0
std1 = 100
X = np.random.normal(center1,std1,N_SAMPLES)


#params of line
m = 3
b = 1


y = X*m + b


#params of gaussian noise
center2 = 0
std2 = 10

noise = np.random.normal(center2,std2,N_SAMPLES)

#mix line and noise
y = y + noise


#plot
fig3, ax3 = plt.subplots()
ax3.scatter(X,y)
plt.show()

# %%
from linreg_test import grad_descent

###
m=0
b=0
epochs = 100000
L = 0.001

for i in range(epochs):
    m, b = grad_descent(m, b, X, y, L)
    if i%1000 == 0:
        print(i,m,b)
# Out:
# 0 5.278113625909364 0.002543005395840012
# 1000 2.990942301990385 1.6554937125884615
# 2000 2.9909966579406273 1.878696849757319
# 3000 2.9910040002702383 1.9088468332658821
# 4000 2.991004992062377 1.9129194530197864
# 5000 2.9910051260323427 1.913469577090505
# 6000 2.9910051441288275 1.9135438871197925
# 7000 2.991005146573277 1.9135539248199156
# 8000 2.99100514690347 1.9135552806991254
# 9000 2.991005146948072 1.9135554638494887
# 10000 2.9910051469540964 1.913555488589196
# 11000 2.991005146954911 1.9135554919310023
# 12000 2.9910051469550205 1.9135554923824099
# 13000 2.991005146955035 1.9135554924433849
# 14000 2.9910051469550374 1.9135554924516223
# 15000 2.9910051469550374 1.9135554924527365
# 16000 2.9910051469550374 1.9135554924528526
# 17000 2.9910051469550374 1.9135554924528526
# 18000 2.9910051469550374 1.9135554924528526
# 19000 2.9910051469550374 1.9135554924528526
# 20000 2.9910051469550374 1.9135554924528526
# 21000 2.9910051469550374 1.9135554924528526
# 22000 2.9910051469550374 1.9135554924528526
# 23000 2.9910051469550374 1.9135554924528526
# 24000 2.9910051469550374 1.9135554924528526
# 25000 2.9910051469550374 1.9135554924528526
# 26000 2.9910051469550374 1.9135554924528526
# 27000 2.9910051469550374 1.9135554924528526
# 28000 2.9910051469550374 1.9135554924528526
# 29000 2.9910051469550374 1.9135554924528526
# 30000 2.9910051469550374 1.9135554924528526
# 31000 2.9910051469550374 1.9135554924528526
# 32000 2.9910051469550374 1.9135554924528526
# 33000 2.9910051469550374 1.9135554924528526
# 34000 2.9910051469550374 1.9135554924528526
# 35000 2.9910051469550374 1.9135554924528526
# 36000 2.9910051469550374 1.9135554924528526
# 37000 2.9910051469550374 1.9135554924528526
# 38000 2.9910051469550374 1.9135554924528526
# 39000 2.9910051469550374 1.9135554924528526
# 40000 2.9910051469550374 1.9135554924528526
